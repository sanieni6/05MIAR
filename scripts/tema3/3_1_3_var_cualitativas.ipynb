# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Doctorado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Master' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Master'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Master' 'Master' 'Secundaria' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Master' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Master' 'Doctorado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Secundaria'
#  'Grado' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Master' 'Doctorado' 'Master' 'Master' 'Doctorado' 'Doctorado'
#  'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Master' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Master' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Master' 'Doctorado' 'Grado' 'Bachillerato'
#  'Master' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Secundaria' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
